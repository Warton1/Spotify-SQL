# %% [markdown]
# # Create a SQLite3 schema to store Spotify data in at least 3rd normal form (3NF), and populate the tables.

# %% [markdown]
# Data source: [https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-01-21/readme.md](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-01-21/readme.md)

# %%
import numpy as np
import pandas as pd
import sqlite3
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
# %load_ext sql

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')

# %% [markdown]
# ## Normalization
#
# - Every table should not have any
#     - duplication
#     - dependencies that are not key or domain constraints

# %%
## check duplicates
df.duplicated().any()
# Out:
# False

# %% [markdown]
# There seem to be no duplicate rows in the data frame.

# %% [markdown]
# ### 1NF
#
# - Split composite entries

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %% [markdown]
# The data frame does not seem to have any compound entries, so the data frame already satisfies the first normal form.

# %% [markdown]
# ### 2NF
#
# - Break partial dependencies
#     - Identify candidate Primary Key for each row
#     - If there is a composite Primary Key, see if other columns have partial dependencies

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %% [markdown]
# In the codebook, `track_id` is the unique ID for each song, so it is possibly the Primary Key.

# %% [markdown]
# #### (1) Playlist:

# %%
playlist = df[df.duplicated(subset=['playlist_id'])]
playlist.sort_values(by = ['playlist_id'], axis=0)[['playlist_id','playlist_name','playlist_genre','playlist_subgenre']].head()
# Out:
#                  playlist_id   playlist_name playlist_genre playlist_subgenre
# 7949  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7935  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7936  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7937  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop
# 7938  0275i1VNfBnsNbPl0QIBpG  Hip-Hop 'n RnB            rap  southern hip hop

# %% [markdown]
# From the above table, we can see that `playlist_name`, `playlist_genre` and `playlist_subgenre` all depend on `playlist_id`.

# %%
df_playlist = df[['playlist_id', 'playlist_name', 'playlist_genre', 'playlist_subgenre']].drop_duplicates()

# %% [markdown]
# #### (2) Album:

# %%
album = df[df.duplicated(subset=['track_album_id'])]
album.sort_values(by = ['track_album_id'], axis=0)[['track_album_id', 'track_album_name', 'track_album_release_date']].head()
# Out:
#                track_album_id              track_album_name  \
# 25103  006AgHXrEw13oyg0D8evRa  Bad Boy Greatest Hits Vol. 1
# 11218  007DWn799UWvfY1wwZeENR                  i am > i was
# 11244  007DWn799UWvfY1wwZeENR                  i am > i was
# 11242  007DWn799UWvfY1wwZeENR                  i am > i was
# 8985   007DWn799UWvfY1wwZeENR                  i am > i was
#
#       track_album_release_date
# 25103                     1998
# 11218               2018-12-21
# 11244               2018-12-21
# 11242               2018-12-21
# 8985                2018-12-21

# %% [markdown]
# From the above table, we can see that `track_album_name` and `track_album_release_date` all depend on `track_album_id`.

# %%
df_album = df[['track_album_id','track_album_name', 'track_album_release_date']].drop_duplicates()

# %% [markdown]
# #### (3) Song:

# %%
song = df[df.duplicated(subset=['track_id'])]
song.sort_values(by = ['track_id'], axis=0)[['track_id','track_name', 'track_artist','track_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                                             'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','duration_ms']].head()
# Out:
#                      track_id                       track_name track_artist  \
# 32084  00Gu3RMpDW2vO9PjlMVFDL    Hide Away (feat. Envy Monroe)  Blasterjaxx
# 23850  00QyLmjxaSEE8qIZQjBXBj       We Own It (Fast & Furious)     2 Chainz
# 28968  00QyLmjxaSEE8qIZQjBXBj       We Own It (Fast & Furious)     2 Chainz
# 9345   00ReeHCY0FQUyuAUyPJdnk  Ain't No Future In Yo' Frontin'     MC Breed
# 14626  00WIXhVVhswHuS6dlkScuw                              Hot     Confetti
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 32084                42         0.573   0.746   10    -4.894     1
# 23850                59         0.554   0.899    8    -4.573     1
# 28968                59         0.554   0.899    8    -4.573     1
# 9345                 48         0.672   0.761    0    -9.644     1
# 14626                51         0.607   0.908    7    -3.883     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 32084       0.0421       0.02490          0.000000    0.3610    0.134
# 23850       0.4080       0.05210          0.000000    0.0568    0.552
# 28968       0.4080       0.05210          0.000000    0.0568    0.552
# 9345        0.2480       0.05140          0.000000    0.4740    0.731
# 14626       0.1070       0.00297          0.000002    0.1200    0.664
#
#          tempo  duration_ms
# 32084  130.001       188000
# 23850  171.966       227893
# 28968  171.966       227893
# 9345   102.192       244733
# 14626  168.015       150714

# %% [markdown]
# From the above table, we can see that `track_name`, `track_popularity` and `track_artist` and other song characteristics all depend on `track_id`.

# %%
df_song = df[['track_id','track_name','track_artist','track_popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']].drop_duplicates()

# %%
df_song_playlist = df[['track_id', 'playlist_id']].drop_duplicates()
df_song_album = df[['track_id', 'track_album_id']].drop_duplicates()

# %% [markdown]
# ### 3NF
#
# - Remove transitive dependencies

# %%
df_playlist_ = df_playlist[['playlist_id', 'playlist_name', 'playlist_subgenre']]
df_playlist_genre = df_playlist[['playlist_subgenre', 'playlist_genre']].drop_duplicates()

# %%
df_playlist_genre
# Out:
#                playlist_subgenre playlist_genre
# 0                      dance pop            pop
# 1298               post-teen pop            pop
# 2427                  electropop            pop
# 3835             indie poptimism            pop
# 5507                     hip hop            rap
# 6829            southern hip hop            rap
# 8504                gangster rap            rap
# 9962                        trap            rap
# 11253                 album rock           rock
# 12318               classic rock           rock
# 13614             permanent wave           rock
# 14719                  hard rock           rock
# 16204                   tropical          latin
# 17492                  latin pop          latin
# 18754                  reggaeton          latin
# 19703              latin hip hop          latin
# 21359         urban contemporary            r&b
# 22764                    hip pop            r&b
# 24020             new jack swing            r&b
# 25153                   neo soul            r&b
# 26790              electro house            edm
# 28301                   big room            edm
# 29507                    pop edm            edm
# 31024  progressive electro house            edm

# %% [markdown]
# ## Final tables

# %%
df_song.sample(5)
# Out:
#                      track_id                      track_name  \
# 19218  4l3xGFwoTinvYxsePytOOf                 Báilame - Remix
# 32446  0XBpFhAb7DokSAhDvCBNY4                   Double Double
# 26668  4GhbRPmkVfAZmSQZqdifrn  ifuleave [feat. Mary J. Blige]
# 20617  5bLrBRYR92X7CddgbVhUqc                Vamos a la Playa
# 16468  2cElznINAHvKeHzv97ZuAV                        Caramelo
#
#           track_artist  track_popularity  danceability  energy  key  loudness  \
# 19218            Nacho                69         0.646   0.865    6    -4.215
# 32446          twoloud                28         0.689   0.984    4    -3.336
# 26668  Musiq Soulchild                45         0.467   0.752   11    -3.244
# 20617         Righeira                 0         0.846   0.853    8    -6.440
# 16468            La Lá                45         0.629   0.189    9   -14.598
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 19218     1       0.0983        0.2690          0.000004    0.1100    0.762
# 32446     1       0.1170        0.0163          0.186000    0.2900    0.415
# 26668     1       0.2320        0.2080          0.000000    0.1640    0.728
# 20617     1       0.0379        0.0179          0.048600    0.0392    0.662
# 16468     1       0.0682        0.9720          0.006590    0.1080    0.441
#
#          tempo  duration_ms
# 19218  191.954       217093
# 32446  123.982       166431
# 26668  122.775       252440
# 20617  128.534       218651
# 16468  118.402       203808

# %%
df_song_album.sample(5)
# Out:
#                      track_id          track_album_id
# 3458   5TQnwwwx5na4rCj6EVcdvV  6gHRLG5Gbjk3vwtgmadx1g
# 8502   0yaMn1bb6b5gJwR3eVudOK  14jLi7wbq1YQEGMEUzpIkK
# 29672  1oSLMJeccvgqel2kyhdd9j  7zfC6BBJDNGfWXOSH9BvR3
# 10653  3G79AJm9H5lKnngSgBT21L  26WTFLXc2Y8ps9P4QuLr27
# 6479   7nn3FDp3e8h2LlNE25nXfH  7kyRRp16g59X6Zm4ID3NjL

# %%
df_song_playlist.sample(5)
# Out:
#                      track_id             playlist_id
# 28525  1CYAEcbhLAluTm47dIFFgZ  5Bx5niVgi3qGQQw06C0RKq
# 13185  6YnhY4SuFyx3gMgeyTlVdI  37i9dQZF1DWVyizF9BJ61m
# 11233  4kfEy7h6bWBS5OaDpccTap  7tkgK1tm9hYkWp7EFyOcAr
# 17127  4sx5kcyZVyRd1okZAJQ7jX  3YdAwfgQLMS4AN2WjRfRlb
# 4737   1ywuaylLSmjHXsZOr0CY9U  5qFXOOxrQVyS4UCq3UilZN

# %%
df_playlist_.sample(5)
# Out:
#                   playlist_id  \
# 24337  3krpccUV68nBGAQbvHEZDC
# 18018  4BmnnqWEQAamNoVjtjrQJP
# 26790  317O0e8iWJLClLGDKtieRe
# 29320  6pPpLz42hUkr8gbMirkAEl
# 2411   4TvZA7Pml7mHLgbwNomlnm
#
#                                            playlist_name playlist_subgenre
# 24337  Swingbeat (old skool), New Jack Swing, R&B, Hi...    new jack swing
# 18018                                  Latin Pop antiguo         latin pop
# 26790                                 Electro House 2020     electro house
# 29320                               ALPAS Music Festival          big room
# 2411                                       post-teen pop     post-teen pop

# %%
df_playlist_genre.sample(5)
# Out:
#       playlist_subgenre playlist_genre
# 25153          neo soul            r&b
# 0             dance pop            pop
# 3835    indie poptimism            pop
# 26790     electro house            edm
# 2427         electropop            pop

# %%
df_album.sample(5)
# Out:
#                track_album_id  track_album_name track_album_release_date
# 814    0CADmCXbIx4F9m6TBwLtFd           'N Sync               1997-05-26
# 1284   5tF2lAa2rh2kU2xIiBzWia  Wanted on Voyage               2014-06-27
# 6076   3SZr5Pco2oqKFORCP3WNj9        Graduation               2007-01-01
# 1175   1aevseu4cRmSeh5OQOLy4J              Help               2019-11-22
# 17118  2DFTa7ls0ZDZKXT2UJsx5u        Praise You               2019-01-18

# %% [markdown]
# ## Store it in Sqlite3

# %%
# Create a database to connect to in memory
cr = sqlite3.connect('spotify.db')

# Store dataframes in the database
df_song.to_sql(name='df_song', con=cr, index = False)
df_song_album.to_sql(name='df_song_album', con=cr, index = False)
df_song_playlist.to_sql(name='df_song_playlist', con=cr, index = False)
df_playlist_.to_sql(name='df_playlist', con=cr, index = False)
df_playlist_genre.to_sql(name='df_playlist_genre', con=cr, index = False)
df_album.to_sql(name='df_album', con=cr, index = False)

# %% [markdown]
# ## Connect

# %%
# %sql sqlite:///spotify.db
# Out:
# 'Connected: @spotify.db'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///spotify.db
# Done.
# [('table', 'df_song', 'df_song', 2, 'CREATE TABLE "df_song" (\n"track_id" TEXT,\n  "track_name" TEXT,\n  "track_artist" TEXT,\n  "track_popularity" INTEGER,\n  "danceability" REAL,\n  "e ... (79 characters truncated) ... hiness" REAL,\n  "acousticness" REAL,\n  "instrumentalness" REAL,\n  "liveness" REAL,\n  "valence" REAL,\n  "tempo" REAL,\n  "duration_ms" INTEGER\n)'),
#  ('table', 'df_song_album', 'df_song_album', 1041, 'CREATE TABLE "df_song_album" (\n"track_id" TEXT,\n  "track_album_id" TEXT\n)'),
#  ('table', 'df_song_playlist', 'df_song_playlist', 1408, 'CREATE TABLE "df_song_playlist" (\n"track_id" TEXT,\n  "playlist_id" TEXT\n)'),
#  ('table', 'df_playlist', 'df_playlist', 1826, 'CREATE TABLE "df_playlist" (\n"playlist_id" TEXT,\n  "playlist_name" TEXT,\n  "playlist_subgenre" TEXT\n)'),
#  ('table', 'df_playlist_genre', 'df_playlist_genre', 1835, 'CREATE TABLE "df_playlist_genre" (\n"playlist_subgenre" TEXT,\n  "playlist_genre" TEXT\n)'),
#  ('table', 'df_album', 'df_album', 1836, 'CREATE TABLE "df_album" (\n"track_album_id" TEXT,\n  "track_album_name" TEXT,\n  "track_album_release_date" TEXT\n)')]

# %%
# %%sql
# SELECT *
# FROM df_song
# LIMIT 5
# Out:
#  * sqlite:///spotify.db
# Done.
# [('6f807x0ima9a1j3VPbc7VN', "I Don't Care (with Justin Bieber) - Loud Luxury Remix", 'Ed Sheeran', 66, 0.748, 0.9159999999999999, 6, -2.634, 1, 0.0583, 0.102, 0.0, 0.0653, 0.518, 122.036, 194754),
#  ('0r7CVbZTWZgbTCYdfa2P31', 'Memories - Dillon Francis Remix', 'Maroon 5', 67, 0.726, 0.815, 11, -4.968999999999999, 1, 0.0373, 0.0724, 0.00421, 0.35700000000000004, 0.693, 99.97200000000001, 162600),
#  ('1z1Hg7Vb0AhHDiEmnDE79l', 'All the Time - Don Diablo Remix', 'Zara Larsson', 70, 0.675, 0.9309999999999999, 1, -3.432, 0, 0.0742, 0.0794, 2.33e-05, 0.11, 0.613, 124.008, 176616),
#  ('75FpbthrwQmzHlBJLuGdC7', 'Call You Mine - Keanu Silva Remix', 'The Chainsmokers', 60, 0.718, 0.93, 7, -3.778, 1, 0.102, 0.0287, 9.43e-06, 0.204, 0.27699999999999997, 121.956, 169093),
#  ('1e8PAfcKUYoKkxPhrHqw4x', 'Someone You Loved - Future Humans Remix', 'Lewis Capaldi', 69, 0.65, 0.833, 1, -4.672, 1, 0.0359, 0.0803, 0.0, 0.0833, 0.725, 123.976, 189052)]

# %% [markdown]
# #### Use an SQL query to find the names of all playlists that contain instrumentals.

# %% [markdown]
# From the codebook, `instrumentalness` represents whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.

# %%
# %%sql
# SELECT COUNT(*) AS num_instrumentals, playlist_name
# FROM df_song
# INNER JOIN df_song_playlist
# ON df_song_playlist.track_id = df_song.track_id
# INNER JOIN df_playlist
# ON df_playlist.playlist_id = df_song_playlist.playlist_id
# WHERE instrumentalness > 0.5
# GROUP BY playlist_name
# ORDER BY num_instrumentals DESC
# Out:
#  * sqlite:///spotify.db
# Done.
# [(92, 'Fitness Workout Electro | House | Dance | Progressive House'),
#  (91, 'Lush Lofi'),
#  (88, 'Underground Party | Hypnotic | Minimal | Acid | Big Room | Tech | Liquid'),
#  (81, 'Jazz Vibes'),
#  (81, 'House Electro 2019'),
#  (78, 'Lo-Fi Beats'),
#  (75, 'Lofi Hip-Hop'),
#  (60, 'Selected House'),
#  (58, '💊ELECTRO-HOUSE-TECH💊'),
#  (54, 'Sunny Beats'),
#  (52, 'Tropical Vibes'),
#  (50, 'Electropop And Play'),
#  (50, 'Electro Posé - Discoveries'),
#  (48, 'Techno House 2020 👽 Best Collection 👻 Top DJ’s Electronic Music - Deep House - Trance - Tech House - Dance - Electro Pop'),
#  (45, 'Deep Electronic Music 2020 & Progressive House'),
#  (44, 'House/Electro/Progressive/Disco/Lofi/Synthwave'),
#  (41, 'Latin Village 2019'),
#  (41, 'Gym (Melbourne Bounce/Progressive House)'),
#  (40, 'Big Room House | Festival Bangers'),
#  (38, 'Nasty Bits'),
#  (37, 'Trap Mojito'),
#  (35, 'Jeff Seid Electro House'),
#  (33, 'big boom room — TOMORROWLAND EDC EDM BIG ROOM AMF ADE DANCE TRANCE HARDWELL TIESTO'),
#  (31, 'Permanent Wave'),
#  (30, 'Ultimate Indie Presents... Best Indie Tracks of the 2010s'),
#  (30, 'BIG-ROOM NEVER DIES !'),
#  (29, 'Indie/Jazz Poptimism'),
#  (29, '2011-2014 House'),
#  (28, 'Gothic / Industrial / Mittelalter / EBM / Futurepop / Gothik / Electropop'),
#  (28, 'Bounce United'),
#  (27, 'Arabic Trap'),
#  (26, 'Electro/Progressive/Club House'),
#  (26, 'Alex Workout'),
#  (25, "Electro House - by Spinnin' Records"),
#  (24, 'City Pop 1985 シティーポップ'),
#  (23, 'Electro House 2020'),
#  (22, 'Big Room EDM'),
#  (21, 'Music&Other Drugs'),
#  (20, 'Hands Up\u200f\u200f\u200b\u200b   \u200d'),
#  (20, 'Big Room Beast'),
#  (19, 'Progressive Rock / Metal - Rock /Metal  Progresivo'),
#  (19, 'Electro Swing'),
#  (19, 'Electro House'),
#  (19, 'Big Room 2019'),
#  (18, 'permanent wave'),
#  (18, 'Waves Pop and EDM'),
#  (18, 'Trending EDM by Nik Cooper'),
#  (18, 'Sick Big Room House Drops | EZUMI'),
#  (18, 'Epic Bass Drops'),
#  (18, "Big Room EDM - by Spinnin' Records"),
#  (16, 'Festival Music 2019 - Warm Up Music (EDM, Big Room & Progressive House)'),
#  (15, '🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/2019🔥'),
#  (15, 'Electro Swing Top 100'),
#  (14, 'Maxi Pop  GOLD (New Wave, Electropop, Synth Pop...)'),
#  (13, 'Trap Nation'),
#  (13, 'Trance Party 2019 by FUTURE TRANCE'),
#  (13, '90s Dance Hits'),
#  (11, 'Tropical Nights'),
#  (11, 'Trap Nation 🔊'),
#  (11, 'PAROOKAVILLE - Big Room'),
#  (11, 'Epic Bass Drops | Best House Mixes'),
#  (11, 'EDM 2019'),
#  (10, 'Tastemakers Ball  -  EDM - POP and FUN'),
#  (10, 'EDM 2020 House & Dance'),
#  (9, '♥ EDM LOVE 2020'),
#  (9, 'Vocal House'),
#  (9, 'Urban contemporary'),
#  (9, 'The Edge of Indie Poptimism'),
#  (9, 'Japanese Funk/Soul/NEO/Jazz/Acid'),
#  (9, 'Electro Vibes'),
#  (9, 'ELECTRO HOUSE 2020'),
#  (9, 'CHRISTIAN ELECTRO / DANCE / EDM'),
#  (9, 'Badass Rock'),
#  (9, 'Afro Psychedelica'),
#  (8, 'Vibra Tropical'),
#  (8, 'Urban Contemporary'),
#  (8, 'Pop Dance Hits'),
#  (8, 'NEO SOUL GUITAR'),
#  (8, 'NEO FUNK AND SOUL'),
#  (8, 'Minitruckin Playlist'),
#  (8, 'GTA V - Radio Mirror Park'),
#  (8, 'Electro Pop | Electropop'),
#  (8, 'Deep-deep Bubble Pop'),
#  (8, 'Dancefloor Beats'),
#  (8, "80's Freestyle/Disco Dance Party (Set Crossfade to 4-Seconds)"),
#  (7, '②⓪①⑨ mixed'),
#  (7, '[EAS]: Festival Big Room'),
#  (7, 'Ultimate Indie Presents... Best Tracks of 2019'),
#  (7, 'SINULOG Festival 2020'),
#  (7, 'Pop Warmup 130 BPM'),
#  (7, 'Indie Poptimism'),
#  (7, 'Hard Rock'),
#  (7, 'Electro House Top Tracks'),
#  (7, 'Club Mix 2020 🍹'),
#  (7, 'Chillout & Remixes 💜'),
#  (7, 'Brand New EDM'),
#  (7, '@deniceemoberg EDM - POP REMIXES'),
#  (6, 'Tropical House'),
#  (6, 'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.'),
#  (6, 'Permanent wave 🌊'),
#  (6, 'Modern Indie Rock // Alternative Rock / Garage Rock / Pop Punk / Grunge / Britpop / Pop Rock'),
#  (6, 'INDIE POP! TUNES'),
#  (6, 'Hard Rock Workout'),
#  (6, 'Fresh EDM | Progressive House | Electro House | Trap | Deep House | Electronic | Future House/Bass'),
#  (6, 'ELECTROPOP🐹'),
#  (6, 'ELECTROPOP EN ESPAÑOL'),
#  (6, 'Bluegrass Covers'),
#  (6, 'BALLARE - رقص'),
#  (6, '70s Hard Rock'),
#  (5, 'keg party jukebox'),
#  (5, 'indie poptimism'),
#  (5, 'The Sound of Permanent Wave'),
#  (5, 'The Pulse of Indie Poptimism'),
#  (5, 'POPTIMISM'),
#  (5, 'Neo-Soul Guitar'),
#  (5, 'Indie Poptimism!'),
#  (5, 'Coldplay – Ghost Stories (Deluxe Edition)'),
#  (5, '< DARK TRAP >'),
#  (4, '◤ Hip Hop Dance Music – Urban – Trap – Breaking Locking Popping Bopping – WOD – World of Dance'),
#  (4, 'Tropical Morning'),
#  (4, 'This Is Scorpions'),
#  (4, "This Is Guns N' Roses"),
#  (4, 'Soul Coffee (The Best Neo-Soul Mixtape ever)'),
#  (4, 'Pop Hits 2000-2019'),
#  (4, 'Neo Soul / Modern Jazz / Smooth Hiphop'),
#  (4, 'Latin Hip Hop/Freestyle'),
#  (4, 'Groovy // Funky // Neo-Soul'),
#  (4, 'Great Pops'),
#  (4, 'Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs'),
#  (4, 'Big Room House'),
#  (4, "80's Songs | Top 💯 80s Music Hits"),
#  (4, "70's Classic Rock"),
#  (3, 'Workout Hard Rock'),
#  (3, 'URBAN NATION'),
#  (3, "Today's Hits (Clean)"),
#  (3, 'This Is: Javiera Mena'),
#  (3, 'Southern California Hip Hop Primer'),
#  (3, 'Soft Rock Drive'),
#  (3, 'Soda Stereo – El Ultimo Concierto'),
#  (3, 'Rap Party 24/7 Radio / Gangsta Rap'),
#  (3, 'Permanent Wave CHDB'),
#  (3, 'LATIN FLOW MIX - Música Cristiana🎵'),
#  (3, 'Hard Rock Workout!'),
#  (3, 'HIP&HOP'),
#  (3, 'HARD ROCK CAFE'),
#  (3, 'EDM TROPICAL'),
#  (3, 'EDM House & Dance'),
#  (3, 'Dance Pop Tunes'),
#  (3, 'Crossfit\u200f\u200f\u200b\u200b   \u200d'),
#  (3, 'Classic Rock Radio'),
#  (3, 'Classic Rock Now'),
#  (3, 'Classic Hard Rock'),
#  (3, 'Big Room House / Bigroom'),
#  (3, '80s Pop & Rock Hits and Album Tracks'),
#  (3, '2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥'),
#  (3, "2000's hard rock"),
#  (2, 'post-teen alternative, indie, pop (large variety)'),
#  (2, 'Tropical House 2020'),
#  (2, 'This Is Janelle Monáe'),
#  (2, 'The Queen - La Discografia Completa'),
#  (2, 'TUNES DANCE AND POP'),
#  (2, 'Southern Rock/Classic Rock'),
#  (2, 'Sad Trap'),
#  (2, 'Rock and Rios'),
#  (2, 'Rock Classics'),
#  (2, 'RUSSIAN Gangster Rap'),
#  (2, 'Pop EDM'),
#  (2, 'Orgulho Tropical'),
#  (2, 'New Jack Swing'),
#  (2, 'Neo-Jazz Soul RnB & Afro'),
#  (2, 'Neo Soul'),
#  (2, 'NEO-soul'),
#  (2, 'Mix ElectroPop//ElectroHouse// DeepHouse 2020'),
#  (2, 'Locker Room'),
#  (2, 'Latest Hits 2020 - Pop, Hip Hop & RnB'),
#  (2, "L' ALBUM ROCK"),
#  (2, 'I didn’t know perm stood for permanent (wave)'),
#  (2, 'House Of The Rising Sun'),
#  (2, "Hip-Hop 'n RnB"),
#  (2, 'Hard Rock Classics 1967-1991 (Party Edition)'),
#  (2, 'Hard Rock Cafe Classics'),
#  (2, 'Happy EDM'),
#  (2, "HIP-HOP: Latin Rap ['89-present]"),
#  (2, 'ELECTROPOP'),
#  (2, 'EDM/POP'),
#  (2, 'EDM - pop remixes'),
#  (2, 'Dance Room'),
#  (2, 'Dance Pop'),
#  (2, 'Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos'),
#  (2, 'ALPAS Music Festival'),
#  (2, 'A Loose Definition of Indie Poptimism'),
#  (2, '90s R&B - The BET Planet Groove/Midnight Love Mix'),
#  (2, '"Permanent Wave"'),
#  (1, 'urban CONTEMPORARY'),
#  (1, 'post teen pop'),
#  (1, 'latin hip hop'),
#  (1, 'Workday: Rock Classics'),
#  (1, 'Vault: Def Leppard Greatest Hits'),
#  (1, 'Ultimate Throwbacks Collection'),
#  (1, 'Trapperz Brasil'),
#  (1, 'Top Urban Underground'),
#  (1, 'Todo Éxitos'),
#  (1, 'The Sound of Indie Poptimism'),
#  (1, 'The Sound of Album Rock'),
#  (1, 'The Cranberries Best Of'),
#  (1, 'The Black Album'),
#  (1, 'Swingbeat (old skool), New Jack Swing, R&B, Hip Hop, Urban'),
#  (1, 'Supernatural Classic Rock'),
#  (1, 'Smooth Hip Hop'),
#  (1, 'Rock Hard'),
#  (1, 'Reggaeton Classics'),
#  (1, 'RAP Gangsta'),
#  (1, "R&B 80's/90's/00's"),
#  (1, 'Pop Remix'),
#  (1, 'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s'),
#  (1, 'Pop Hits 2020'),
#  (1, 'Pop EDM Remixes'),
#  (1, 'Pop / Dance'),
#  (1, 'New Jack Swing/ R&B Hits: 1987 - 2002'),
#  (1, 'New Jack City'),
#  (1, 'New House   \u200d'),
#  (1, 'New Hard Rock'),
#  (1, 'Neo-Soul Essentials'),
#  (1, 'Neo-Soul / Soulful R&B'),
#  (1, 'Neo-Soul'),
#  (1, 'Neo Soul Music'),
#  (1, 'Neo Soul 2019'),
#  (1, 'Most Popular 2020 TOP 50'),
#  (1, 'HARD ROCK Vibes'),
#  (1, 'Gangsta Rap 💎 Rap Party'),
#  (1, 'Fresh Essentials'),
#  (1, 'F**KIN PERFECT'),
#  (1, 'Electropop Hits  2017-2020'),
#  (1, 'Electropop - Pop'),
#  (1, 'ElectroPop 2020'),
#  (1, "Dr. Q's Prescription Playlist💊"),
#  (1, 'Contemporary Hip Hop'),
#  (1, 'Classic Rock Retrogamer'),
#  (1, 'Classic Rock Playlist.'),
#  (1, 'Classic Rock Legends'),
#  (1, 'Classic Rock Greatest Hits'),
#  (1, 'Classic Rock Drive'),
#  (1, 'Classic Rock'),
#  (1, 'Christian Dance Party'),
#  (1, 'Blues Rock'),
#  (1, '90s-2000s Southern Hip Hop / Crunk'),
#  (1, '90s Hiphop / Gangsta Rap'),
#  (1, '90s Gangsta Rap / Top Hip-hop Classics'),
#  (1, "90's Southern Hip Hop"),
#  (1, "90's Gangster Rap"),
#  (1, '80s-90s R&B / New Jack Swing / Funk / Dance / Soul'),
#  (1, '80s / Classic Rock'),
#  (1, '70s Pop & Rock Hits and Deep Tracks'),
#  (1, '3rd Coast Classics'),
#  (1, '2019 in Indie Poptimism'),
#  (1, '10er Playlist')]

# %%
# %%sql
# SELECT COUNT(*)
# FROM
# (SELECT COUNT(*) AS num_instrumentals, playlist_name
# FROM df_song
# INNER JOIN df_song_playlist
# ON df_song_playlist.track_id = df_song.track_id
# INNER JOIN df_playlist
# ON df_playlist.playlist_id = df_song_playlist.playlist_id
# WHERE instrumentalness > 0.5
# GROUP BY playlist_name
# HAVING num_instrumentals > 0
# ORDER BY num_instrumentals DESC)
# Out:
#  * sqlite:///spotify.db
# Done.
# [(256,)]

# %% [markdown]
# There are 256 playlists that had at least one song that contains instrumentals.

# %% [markdown]
# ##### check with the original dataframe

# %%
np.sum(df[df.playlist_name == 'Lush Lofi'].instrumentalness > 0.5 )
# Out:
# 91

# %% [markdown]
# This is the same as the result in SQL query.
